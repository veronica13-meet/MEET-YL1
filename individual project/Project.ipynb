# %% [markdown]
# Veronica Morcos.
# I got this dataset from the UN data bank.

# %%
import csv

# %%
f = open('mobile_subscriptions.csv','rb')
reader = csv.reader(f)
Year = []
Value = []
index = 0
for row in reader :
    if index == 0:
        header = row
    else:
        #print row
    
        Year.append(row[0])
        Value.append(row[9])
    index+=1

Year = map(int, Year)
Value = map(int, Value)

print Year 
print Value
        
f.close()
# Out:
# [2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988]
# [3322837, 3210802, 3865354, 2191500, 1442000, 1876411, 1259762, 318044, 203309, 114379, 71349, 25504, 17486, 8161, 7831, 5000, 300, 0, 0, 0, 0, 0, 0, 0, 0]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title('Mobile Subscriptions in Armenia')
ax.set_xlabel('Year')
ax.set_ylabel('Value')
ax.plot(Year , Value)
fig.savefig("mobile_subscriptions.png")

# %% [raw]
# This plot explains the number of mobile subscriptions in Armenia from 1988 until 2012.
